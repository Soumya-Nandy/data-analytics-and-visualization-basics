# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### LINE PLOT

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from numpy.random import randint

# %%
x=np.linspace(1,10,20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y=randint(1,50,20)
y
# Out:
# array([41, 31, 28, 44, 32, 21,  7, 10, 28, 48, 36, 20, 13, 19, 11, 35, 34,
#        44,  4, 13])

# %%
plt.plot(y)

# %%
y=y.cumsum()

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, color='r', marker='o')

# %%
plt.plot(x,y, color='r', marker='o', linestyle='dashed')

# %% [markdown]
# ### Label

# %%
plt.plot(x,y, color='r', marker='o', linestyle='dashed')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('This is a demo plot')
plt.show()

# %% [markdown]
# ### Scatter, Bar, Hist & Box Plots

# %% [markdown]
# Scatter Plot

# %%
x, y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 41,  72, 100, 144, 176, 197, 204, 214, 242, 290, 326, 346, 359,
#         378, 389, 424, 458, 502, 506, 519], dtype=int32))

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y, linewidths=5)
plt.show()

# %% [markdown]
# Bar Plot

# %%
a=['a','b','c','d','e']
b=[10,22,65,34,55]

plt.bar(a,b)
plt.show()

# %%
plt.bar(a,b, width=0.3)
plt.show()

# %% [markdown]
# Histogram Plot

# %%
plt.hist(y)
# Out:
# (array([2., 1., 2., 3., 1., 2., 2., 2., 2., 3.]),
#  array([ 41. ,  88.8, 136.6, 184.4, 232.2, 280. , 327.8, 375.6, 423.4,
#         471.2, 519. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y, rwidth=0.8, bins= 20)
# Out:
# (array([1., 1., 1., 0., 1., 1., 2., 1., 1., 0., 1., 1., 1., 1., 2., 0., 1.,
#         1., 0., 3.]),
#  array([ 41. ,  64.9,  88.8, 112.7, 136.6, 160.5, 184.4, 208.3, 232.2,
#         256.1, 280. , 303.9, 327.8, 351.7, 375.6, 399.5, 423.4, 447.3,
#         471.2, 495.1, 519. ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Box Plot

# %%
data=[np.random.normal(0, std, 100) for std in range(1,3)]

# %%
data
# Out:
# [array([-0.3276749 ,  0.50306753,  1.00554921,  0.57468582,  1.55668004,
#         -0.41891835, -0.40971692,  1.11637454, -0.2509793 , -0.41522808,
#         -0.63908615,  2.49776759, -3.00512816, -0.87399723, -2.65018924,
#          1.12400545, -0.21363701,  1.13183157,  0.03723304,  1.30275033,
#          0.24990045, -0.64586771,  0.47119601, -0.39810329, -0.95921519,
#          0.54087305, -0.07824546,  1.83379274,  1.0246933 , -0.08166743,
#         -2.62754439, -0.35645775, -0.09860287, -1.3003954 ,  0.28873961,
#          1.45137755, -0.17791818, -0.16990685,  0.55012716,  2.09628076,
#         -0.87680291, -0.43299184, -0.84589888,  0.16373274,  0.29839875,
#          0.23766958, -0.15580481, -0.8595119 ,  2.5290124 , -0.84448494,
#          0.89066205,  0.77200376,  0.02031364, -1.58325014,  0.07544465,
#          0.5921135 ,  0.2407829 , -0.79654715, -0.06139562,  0.06509959,
#          0.2486498 , -0.75473057,  1.69943135, -0.39274665, -0.86249519,
# ...

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f8907f520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f8907fbe0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f8907f1c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f8908b2e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f8908b640>,
# ...
#  'means': []}

# %%
plt.boxplot(data, vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f890e6c70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f890f3370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f890e6910>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f890f3a30>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f890f3d90>,
# ...
#  'means': []}

# %%
plt.boxplot(data, vert=True, patch_artist=True)
plt.show()

# %% [markdown]
# Subplots

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([ 41,  72, 100, 144, 176, 197, 204, 214, 242, 290, 326, 346, 359,
#        378, 389, 424, 458, 502, 506, 519], dtype=int32)

# %%
y2=y*x

# %%
plt.plot(x,y)
plt.plot(x,y2)

# %%
plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(x,y2)

# %%
plt.subplot(1,2,1)
plt.plot(x,y, marker='o',color='b')

plt.subplot(1,2,2)
plt.plot(x,y2,marker='*',color='g',markersize=8)

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.1,0.6,0.4,0.3])

ax1.plot(x,y,'r')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('y plot')

ax2.plot(x,y2,'g')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('x plot')

plt.show()

# %% [markdown]
# xlim, ylim, xticks & yticks

# %%
fig,ax = plt.subplots(1,2, figsize=(12,4))
ax[0].plot(x,y,x,y2)

ax[1].plot(x,y,x,y**2, color='b')

# %%
fig,ax = plt.subplots(1,2, figsize=(12,4))
ax[0].plot(x,y,x,y2)

ax[1].plot(x,y,x,y**2, color='b')

ax[1].set_ylim([0,1500])
ax[1].set_xlim([-5,8])
# Out:
# (-5.0, 8.0)

# %%
fig,ax = plt.subplots(1,2, figsize=(12,4))
ax[0].plot(x,y,x,y2)
ax[1].plot(x,y,x,y**2, color='b')
ax[0].set_xticks([1,3,5])
ax[0].set_xticklabels([r'$\alpha$',r'$\beta$',r'$\delta$'])

plt.show()

# %% [markdown]
# PIE PLOT

# %%
labels=['cat', 'dog', 'lion', 'elephant']
size=[15, 25, 35, 50]

# %%
fig, ax=plt.subplots(figsize=(4,4), dpi= 100)
explode=(0,0.2,0,0)
ax.pie(size, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90,explode=explode,)
plt.show()

# %% [markdown]
# PIE PLOT TEXT COLOR

# %%
fig, ax=plt.subplots(figsize=(4,4), dpi= 100)
explode=(0,0.2,0,0)
patches, texts, autotexts = ax.pie(size, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90,explode=explode,)
plt.setp(autotexts, size=10, color='white')
autotexts[1].set_color('black')
plt.show()

# %% [markdown]
# NESTED PIE CHART

# %%
fig, ax = plt.subplots(dpi = 100)
size= 0.3
vals=np.array([[60,32],[35,20],[26,36]])
vals_sum=vals.sum(axis=1)
vals_flat=vals.flatten()

cmap=plt.get_cmap('tab20c')
outer_colors=cmap(np.arange(3)*4)
inner_colors=cmap(np.arange(3)*6)

ax.pie(vals_sum, radius=1, colors=outer_colors, wedgeprops= dict(width=size, edgecolor='white'))

ax.pie(vals_flat, radius=1-size, colors=inner_colors, wedgeprops= dict(width=size, edgecolor='white'))

plt.show()

# %% [markdown]
# ### Lableing a Pie Plot

# %%
fig,ax=plt.subplots(dpi=100)    # dpi = dot per inches in a perticular figure
recipe=["375 g flour", "75 g sugar", "250 g butter", "300 g berries"]

data=[float(x.split(' ')[0])for x in recipe]
ingredients=[x.split(' ')[-1] for x in recipe]

def func(pct,vals):
    absolute=int(pct/100.*np.sum(vals))
    return "{:.1f}%\n({:d}) g".format(pct, absolute)

wedges, autotexts, texts = ax.pie(data, autopct= lambda pct: func(pct,data), textprops=dict(color='w'))
ax.legend(wedges,ingredients, title='ingredients', loc='center left',bbox_to_anchor=(1,0,1,1))
plt.show()

# %% [markdown]
# ### Bar Chart On Ploar Axis

# %%
np.random.seed(0)
N=20
theta=np.linspace(0.0,2*np.pi,N, endpoint=False)
radii=10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
colors=plt.cm.plasma(radii/10)

plt.figure(dpi=100)
ax=plt.subplot(1,1,1, projection='polar')
ax.bar(theta,radii, width=width, bottom=0, color=colors, alpha=0.7)
plt.show()

# %% [markdown]
# ### Line Plot On a Polar Axis

# %%
r = np.arange(0,2,0.01)
theta=2*np.pi*r
plt.figure(dpi=100)
ax=plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.0,0.5,1,1.5])
ax.set_rlabel_position(-30)
ax.grid(True)                   #ax.grid(False)
plt.show()

# %% [markdown]
# ### Scatter Plot On a Ploar Axis

# %%
np.random.seed(0)
N=150
r=2*np.random.rand(N)
theta=2*np.pi*np.random.rand(N)
area=50*2*np.pi*r**2
colors=theta

fig=plt.figure(dpi=100)
ax=fig.add_subplot(111,projection='polar')
c=ax.scatter(theta,r,c=colors,s=area, cmap='hsv', alpha=0.8)
plt.show()

# %% [markdown]
# ### Integral as the area under a curve

# %%
from matplotlib.patches import Polygon

# %%
def func(x):
    return (x-3)*(x-5)*(x-7)+85
a, b = 2, 9
x=np.linspace(0,10)
y=func(x)

fig,ax=plt.subplots(dpi=100)
ax.plot(x,y,'r',linewidth=2)
ax.set_ylim(bottom=0)

ix=np.linspace(a,b)
iy=func(ix)
verts=[(a,0),*zip(ix,iy),(b,0)]
poly=Polygon(verts,facecolor = '0.9', edgecolor= '0.5')
ax.add_patch(poly)

ax.text(0.5*(a+b),30,r"$\int_a^b f(x)dx$", horizontalalignment='center', fontsize=20)

fig.text(0.9,0.05,'x')
fig.text(0.1,0.9,'y')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_ticks_position('bottom')
ax.set_xticks((a,b))
ax.set_xticklabels(('a','b'))
ax.set_yticks([])
plt.show()

# %% [markdown]
# ### Real Time CPU Uses Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from matplotlib.animation import FuncAnimation

# %%
from psutil import cpu_percent

# %%
cpu_percent()
# Out:
# 3.3

# %%
uses=[]

# %%
cpu_use=cpu_percent()
uses.append(cpu_use)
print(cpu_use)
# Out:
# 2.3

# %%
print(uses)
# Out:
# [2.3]

# %%
plt.plot(uses)
plt.show()

# %%
# %matplotlib notebook

frame_len=200

y=[]

fig=plt.figure(figsize=(8,4))

def animate(i):
    y.append(cpu_percent())
    
    if len(y)<= frame_len:
        plt.cla()
        plt.plot(y,'r',label='Real Time CPU Uses')
    else:
        plt.cla()
        plt.plot(y[-frame_len:],'r', label='Real-Time CPU Uses')
     
    """plt.ylim(0,100)
    plt.xlabel('Time(s)')
    plt.ylabel('CPU Uses(%)')
    plt.legend(loc='upper-right')
    plt.tight_layout()"""
    
ani= FuncAnimation(plt.gcf(),animate, interval=1000)
# Out:
# <img src="data:," width="0">
