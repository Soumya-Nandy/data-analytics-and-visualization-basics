# %% [markdown]
# DATA VISUALIZATION WITH PANDAS

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Generating Data

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df=pd.DataFrame(randn(1000), index=pd.date_range('2019-06-07', periods=1000),columns=['value']) 
#inciment date by 1 day

# %%
df
# Out:
#                value
# 2019-06-07  0.660070
# 2019-06-08  0.018265
# 2019-06-09 -0.163256
# 2019-06-10  0.104309
# 2019-06-11 -1.003584
# ...              ...
# 2022-02-26 -0.061889
# 2022-02-27  0.251961
# 2022-02-28  0.324126
# 2022-03-01  0.339134
# 2022-03-02  0.981624
#
# [1000 rows x 1 columns]

# %%
ts=pd.Series(randn(1000), index=pd.date_range('2019-06-07', periods=1000))
#generating random values against date

# %%
ts
# Out:
# 2019-06-07   -0.128435
# 2019-06-08   -0.934311
# 2019-06-09    0.498357
# 2019-06-10   -0.594832
# 2019-06-11    0.391682
#                 ...
# 2022-02-26   -1.767290
# 2022-02-27   -0.886449
# 2022-02-28   -0.138486
# 2022-03-01   -0.584401
# 2022-03-02    1.081862
# Freq: D, Length: 1000, dtype: float64

# %%
df['value']=df['value'].cumsum()  #cumsum() stands for cumulative sum
df.head()
# Out:
#                value
# 2019-06-07  0.660070
# 2019-06-08  0.678335
# 2019-06-09  0.515080
# 2019-06-10  0.619388
# 2019-06-11 -0.384196

# %%
ts=ts.cumsum()  #in time series we need not to pass column name
ts.head()
# Out:
# 2019-06-07   -0.128435
# 2019-06-08   -1.062746
# 2019-06-09   -0.564388
# 2019-06-10   -1.159221
# 2019-06-11   -0.767538
# Freq: D, dtype: float64

# %%
#Line Plot
ts.plot()
# Out:
# <AxesSubplot:>

# %%
#increase the size of the plot
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
#load dataset using seaborn
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
iris.plot(legend=False, figsize=(10,5), logy=True)
# Out:
# <AxesSubplot:>

# %%
x=iris.drop(labels=['sepal_width','petal_width'],axis=1)
x.head()
# Out:
#    sepal_length  petal_length species
# 0           5.1           1.4  setosa
# 1           4.9           1.4  setosa
# 2           4.7           1.3  setosa
# 3           4.6           1.5  setosa
# 4           5.0           1.4  setosa

# %%
y=iris[['sepal_width','petal_width']]
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax=x.plot()
y.plot(secondary_y=True,ax=ax,figsize=(16,10))
# Out:
# <AxesSubplot:label='4498b1be-12f4-4cfd-ba06-8a65c50af417'>

# %% [markdown]
# BAR PLOT

# %%
df=iris.drop(['species'],axis=1)

# %%
df.iloc[0]  #iloc locks the data in a perticullar row, here it is zero
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#loading titanic dataset

titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind= 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['survived'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Stacked Plot

# %%
df= pd.DataFrame(randn(10,4), columns=['a','b','c','d'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.875044  0.232098 -0.293202 -0.105548
# 1  0.218229 -1.075469 -1.222041  0.118800
# 2  0.095352  0.687408 -0.684807 -2.675350
# 3 -1.966606  0.683652  0.371179  0.046732
# 4  0.503863  1.170979 -0.682996  2.196976

# %%
df.plot.bar(stacked='True')
# Out:
# <AxesSubplot:>

# %%
#ploting stack horizontally
df.plot.barh(stacked='True')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Histogram Plotting

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=30) #making lines thinner
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# stacked plot with histogram
iris.plot(kind='hist', bins=50, stacked='True')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=50, stacked='True', orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['petal_length'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=iris.drop('species',axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.diff().hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(color='r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(color='r',alpha=0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(color='b',alpha=0.9)
plt.show()

# %% [markdown]
# BOX PLot

# %%
df.plot(kind='box',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind='box',figsize=(10,5), vert=False)
# Out:
# <AxesSubplot:>

# %%
df['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
df['sepal_length'].median()
# Out:
# 5.8

# %% [markdown]
# AREA & SCATTER PLOT

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_width',y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_width',y='petal_width', c='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
ax=df.plot.scatter(x='sepal_width',y='petal_width', label='width')
df.plot.scatter(x='sepal_length',y='petal_length',ax=ax,color='r')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# HEX & PIE PLOT

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',C='sepal_width',gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.iloc[0].plot.pie()
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d=df.head(2).T
d
# Out:
#                 0    1
# sepal_length  5.1  4.9
# sepal_width   3.5  3.0
# petal_length  1.4  1.4
# petal_width   0.2  0.2

# %%
d.plot.pie(subplots=True, figsize=(30,30))
plt.show()

# %%
d.plot.pie(subplots=True, figsize=(30,30), fontsize=25)  #incrise font size
plt.show()

# %%
#showing percentage 
d.plot.pie(subplots=True, figsize=(30,30), fontsize=25, autopct='%.2f')
plt.show()

# %% [markdown]
# Scatter Matrix & Subplots

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(10,10), diagonal='kde', color='r')  # kde= kernel density estimated plot
plt.show()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots=True)
plt.show()

# %%
df.plot(subplots=True, sharex=False)
plt.show()

# %%
df.plot(subplots=True, sharex=False)
plt.tight_layout()
plt.show()

# %%
df.plot(subplots=True, sharex=False,layout=(2,2), figsize=(10,6))
plt.tight_layout
plt.show()
